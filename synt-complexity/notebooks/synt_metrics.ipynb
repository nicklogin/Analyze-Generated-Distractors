# %%
import json, warnings

from typing import Union

import numpy as np
import pandas as pd
import scipy

from syntaxcomp import TextComplexity

# %%
with open("../data/data_dict_conll_spacy.json", 'r', encoding="utf8") as inp:
    data_dict_conll = json.load(inp)

# %%
with open("../data/data_dict.json", 'r', encoding="utf8") as inp:
    data_dict = json.load(inp)

# %%
comp = TextComplexity(data_dict_conll["BartDG"][0])

# %%
print(comp.info(print_=False))
# Out:
# {'Number of Sentences': 1, 'Number of Words': 5, 'Number of Clauses': 1, 'Number of T-Units': 1, 'Mean Sentence Length': 5.0, 'Mean Clause Length': 5.0, 'Mean T-Unit Length': 5.0, 'Mean Number of Clauses per Sentence': 1.0, 'Mean Number of Clauses per T-Unit': 1.0, 'Mean Tree Depth': 3, 'Median Tree Depth': 3, 'Minimum Tree Depth': 3, 'Maximum Tree Depth': 3, 'Mean Dependency Distance': 1.8, 'Node-to-Terminal-Node Ratio': 1.67, 'Average Levenshtein Distance between POS': 0, 'Average Levenshtein Distance between deprel': 0, 'Average NP Length': 1.5, 'Complex NP Ratio': 0.5, 'Number of Combined Clauses': 0, 'Number of Coordinate Clauses': 0, 'Number of Subordinate Clauses': 0, 'Coordinate to Combined Clause Ratio': 0, 'Subordinate to Combined Clause Ratio': 0, 'Coordinate to Subordinate Clause Ratio': 0, 'Coordinate Clause to Sentence Ratio': 0.0, 'Subordinate Clause to Sentence Ratio': 0.0, 'ROOT_ratio': 1.0, 'root_ratio': 0.0, 'acl_ratio': 0.0, 'acl:relcl_ratio': 0.0, 'advcl_ratio': 0.0, 'advcl:relcl_ratio': 0.0, 'ccomp_ratio': 0.0, 'csubj_ratio': 0.0, 'csubj:outer_ratio': 0.0, 'nsubj:outer_ratio': 0.0, 'parataxis_ratio': 0.0, 'xcomp_ratio': 0.0, 'conj_ratio': 0.0}

# %%
def analyze(s: str) -> dict[str, Union[float, int]]:
    result = TextComplexity(s).info(print_=False)
    return result

# %%
data_with_syn_scores = {key: [] for key in data_dict}

for key in data_dict:
    distractor_set_id = 0
    distractor_id = 0
    for distractor_set in data_dict[key]:
        for d_id_inset, distractor in enumerate(distractor_set):
            distractor_parse = data_dict_conll[key][distractor_id]
            try:
                item = {
                    "distractor_set_id": distractor_set_id,
                    "distractor_id": distractor_id,
                    "distractor_text": distractor,
                    "distractor_parse": distractor_parse,
                }
                if distractor_parse:
                    try:
                        item = {**item, **analyze(distractor_parse)}
                    except Exception as exc:
                        warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
                data_with_syn_scores[key].append(item)
            except Exception as exc:
                print(key, distractor_set_id, d_id_inset, distractor_id, distractor)
                raise exc
            distractor_id += 1
        distractor_set_id += 1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: BartDG_PM, 34, 2, .
# The annotation is empty!
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_GPT3, 3, 2, Домой.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_GPT3, 15, 0, Тогда, когда нечего будет есть.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_GPT3, 15, 1, Тогда, когда нечего будет пить.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_GPT3, 15, 2, Тогда, когда нечего было есть.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_GPT3, 42, 1, Не умеет любить.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_T5, 21, 1, Чтобы не быть униженным и оскорблённым.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_T5, 41, 0, Читать.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_T5, 52, 1, Чтобы не остаться в живых.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")
# C:\Users\User\AppData\Local\Temp\ipykernel_8892\3408369452.py:20: UserWarning: MuSeRC_T5, 53, 0, Чтобы не оставаться одной.
# mean requires at least one data point
#   warnings.warn(f"{key}, {distractor_set_id}, {d_id_inset}, {distractor}\n{str(exc)}")

# %%
## Dump data to different sheets:
writer = pd.ExcelWriter(
    "../data/syntaxcomp_metrics_spacy.xlsx",
    engine="xlsxwriter"
)

for key in data_with_syn_scores:
    df = pd.DataFrame(data_with_syn_scores[key])
    df.to_excel(writer, sheet_name=key)

writer.close()

# %%
## Dump data to one sheet
data_with_scores_ = []

for key in data_with_syn_scores:
    df = [
        {"Source": key, **item} for item in data_with_syn_scores[key]
    ]
    data_with_scores_ += df

data_with_scores_ = pd.DataFrame(data_with_scores_)
data_with_scores_.head()

# %%
## Compute averaged table
averaged_table = None

for key in data_with_syn_scores:
    df = pd.DataFrame(data_with_syn_scores[key])

    # print(key, "Number of words between:", df["Number of Words"].min(), df["Number of Words"].max())
    # print(key, "Number of sents between:", df["Number of Sentences"].min(), df["Number of Sentences"].max())
    # print(key, "Number of clauses between:", df["Number of Clauses"].min(), df["Number of Clauses"].max())
    # print(key, "Number of T-units between:", df["Number of T-Units"].min(), df["Number of T-Units"].max())

    row = df.drop(
        [
            "distractor_set_id",
            "distractor_id",
            "distractor_text",
            "distractor_parse"
        ], axis="columns"
    ).mean()
    if averaged_table is None:
        averaged_table = pd.DataFrame(
            columns = [col for col in row.keys()] + ["Distractors/Question"]
        )
    row["Distractors/Question"] = df["Number of Clauses"].notna().sum() / 55
    averaged_table.loc[key] = row

# %%
averaged_table.T
# Out:
#                                                BartDG  BartDG_PM  BartDG_ANPM  \
# Number of Sentences                          1.036145   1.060241     1.036145
# Number of Words                              7.927711   9.138554     8.753012
# Number of Clauses                            1.469880   1.837349     1.891566
# Number of T-Units                            1.138554   1.144578     1.072289
# Mean Sentence Length                         7.798193   8.750482     8.652590
# Mean Clause Length                           5.867530   5.630964     5.274036
# Mean T-Unit Length                           7.245000   8.300663     8.438735
# Mean Number of Clauses per Sentence          1.430723   1.754518     1.855422
# Mean Number of Clauses per T-Unit            1.303193   1.647048     1.801205
# Mean Tree Depth                              3.719398   3.960843     4.068253
# Median Tree Depth                            3.713855   3.951807     4.060241
# Minimum Tree Depth                           3.704819   3.915663     4.054217
# Maximum Tree Depth                           3.740964   4.018072     4.090361
# Mean Dependency Distance                     2.229819   2.182470     2.117410
# Node-to-Terminal-Node Ratio                  1.923133   1.843072     1.822048
# Average Levenshtein Distance between POS     0.071265   0.413675     0.050241
# Average Levenshtein Distance between deprel  0.068253   0.425723     0.054277
# Average NP Length                            2.208916   2.169398     1.981145
# Complex NP Ratio                             0.667831   0.621506     0.539578
# Number of Combined Clauses                   0.433735   0.777108     0.855422
# Number of Coordinate Clauses                 0.102410   0.084337     0.036145
# Number of Subordinate Clauses                0.331325   0.692771     0.819277
# Coordinate to Combined Clause Ratio          0.075301   0.057711     0.022048
# Subordinate to Combined Clause Ratio         0.292169   0.484458     0.520120
# Coordinate to Subordinate Clause Ratio       0.045181   0.041145     0.018072
# Coordinate Clause to Sentence Ratio          0.102410   0.078313     0.036145
# Subordinate Clause to Sentence Ratio         0.328313   0.676205     0.819277
# ROOT_ratio                                   0.807229   0.698996     0.682731
# root_ratio                                   0.000000   0.000000     0.000000
# acl_ratio                                    0.011044   0.056426     0.016566
# acl:relcl_ratio                              0.035643   0.033835     0.013052
# advcl_ratio                                  0.034137   0.049297     0.077811
# advcl:relcl_ratio                            0.000000   0.000000     0.000000
# ccomp_ratio                                  0.017068   0.053414     0.096888
# csubj_ratio                                  0.009036   0.021084     0.019578
# csubj:outer_ratio                            0.000000   0.000000     0.000000
# nsubj:outer_ratio                            0.000000   0.000000     0.000000
# parataxis_ratio                              0.010542   0.013052     0.003012
# xcomp_ratio                                  0.044177   0.055120     0.080321
# conj_ratio                                   0.031124   0.018775     0.010040
# Distractors/Question                         3.018182   3.018182     3.018182
#
#                                              MuSeRC_GPT3  MuSeRC_T5  \
# Number of Sentences                             1.006494   1.011765
# Number of Words                                 5.324675   7.447059
# Number of Clauses                               1.525974   1.682353
# Number of T-Units                               1.136364   1.117647
# Mean Sentence Length                            5.282468   7.311765
# Mean Clause Length                              3.668896   4.814824
# Mean T-Unit Length                              4.781364   6.758824
# Mean Number of Clauses per Sentence             1.512987   1.652941
# Mean Number of Clauses per T-Unit               1.361429   1.505882
# Mean Tree Depth                                 3.081169   3.735294
# Median Tree Depth                               3.081169   3.735294
# Minimum Tree Depth                              3.077922   3.729412
# Maximum Tree Depth                              3.084416   3.741176
# Mean Dependency Distance                        1.838182   2.016588
# Node-to-Terminal-Node Ratio                     1.789935   1.924118
# Average Levenshtein Distance between POS        0.058442   0.094118
# Average Levenshtein Distance between deprel     0.058442   0.129412
# Average NP Length                               1.682532   1.707294
# Complex NP Ratio                                0.440909   0.468588
# Number of Combined Clauses                      0.519481   0.670588
# Number of Coordinate Clauses                    0.129870   0.105882
# Number of Subordinate Clauses                   0.389610   0.564706
# Coordinate to Combined Clause Ratio             0.089805   0.072471
# Subordinate to Combined Clause Ratio            0.286818   0.362824
# Coordinate to Subordinate Clause Ratio          0.038961   0.047059
# Coordinate Clause to Sentence Ratio             0.126623   0.105882
# Subordinate Clause to Sentence Ratio            0.386364   0.547059
# ROOT_ratio                                      0.791883   0.747843
# root_ratio                                      0.000000   0.000000
# acl_ratio                                       0.011905   0.012157
# acl:relcl_ratio                                 0.003788   0.021961
# advcl_ratio                                     0.017749   0.027843
# advcl:relcl_ratio                               0.000000   0.000000
# ccomp_ratio                                     0.015152   0.041176
# csubj_ratio                                     0.007576   0.010784
# csubj:outer_ratio                               0.000000   0.000000
# nsubj:outer_ratio                               0.000000   0.000000
# parataxis_ratio                                 0.022727   0.009804
# xcomp_ratio                                     0.101623   0.097059
# conj_ratio                                      0.027597   0.031373
# Distractors/Question                            2.800000   1.545455
#
#                                              RuRace_GPT3  RuRace_T5  \
# Number of Sentences                             1.000000   1.000000
# Number of Words                                 9.641026   8.693750
# Number of Clauses                               1.801282   1.856250
# Number of T-Units                               1.102564   1.143750
# Mean Sentence Length                            9.641026   8.693750
# Mean Clause Length                              6.195897   5.273000
# Mean T-Unit Length                              9.100449   7.971875
# Mean Number of Clauses per Sentence             1.801282   1.856250
# Mean Number of Clauses per T-Unit               1.658141   1.671875
# Mean Tree Depth                                 4.121795   3.818750
# Median Tree Depth                               4.121795   3.818750
# Minimum Tree Depth                              4.121795   3.818750
# Maximum Tree Depth                              4.121795   3.818750
# Mean Dependency Distance                        2.311154   2.294313
# Node-to-Terminal-Node Ratio                     1.864103   1.820562
# Average Levenshtein Distance between POS        0.000000   0.000000
# Average Levenshtein Distance between deprel     0.000000   0.000000
# Average NP Length                               2.104231   1.910937
# Complex NP Ratio                                0.593590   0.524000
# Number of Combined Clauses                      0.801282   0.856250
# Number of Coordinate Clauses                    0.102564   0.143750
# Number of Subordinate Clauses                   0.698718   0.712500
# Coordinate to Combined Clause Ratio             0.067821   0.107250
# Subordinate to Combined Clause Ratio            0.457821   0.524000
# Coordinate to Subordinate Clause Ratio          0.043782   0.062500
# Coordinate Clause to Sentence Ratio             0.102564   0.143750
# Subordinate Clause to Sentence Ratio            0.698718   0.712500
# ROOT_ratio                                      0.697009   0.647917
# root_ratio                                      0.000000   0.000000
# acl_ratio                                       0.035791   0.015625
# acl:relcl_ratio                                 0.034722   0.035937
# advcl_ratio                                     0.070940   0.083854
# advcl:relcl_ratio                               0.000000   0.000000
# ccomp_ratio                                     0.044872   0.054167
# csubj_ratio                                     0.005342   0.014063
# csubj:outer_ratio                               0.000000   0.000000
# nsubj:outer_ratio                               0.000000   0.000000
# parataxis_ratio                                 0.008761   0.035937
# xcomp_ratio                                     0.072756   0.089063
# conj_ratio                                      0.029808   0.023438
# Distractors/Question                            2.836364   2.909091
#
#                                               Deepseek  ChatGPT4o  \
# Number of Sentences                           1.000000   1.000000
# Number of Words                              13.036364   9.460606
# Number of Clauses                             2.254545   1.745455
# Number of T-Units                             1.400000   1.169697
# Mean Sentence Length                         13.036364   9.460606
# Mean Clause Length                            6.669636   6.128303
# Mean T-Unit Length                           10.387879   8.469697
# Mean Number of Clauses per Sentence           2.254545   1.745455
# Mean Number of Clauses per T-Unit             1.729273   1.536364
# Mean Tree Depth                               4.896970   4.266667
# Median Tree Depth                             4.896970   4.266667
# Minimum Tree Depth                            4.896970   4.266667
# Maximum Tree Depth                            4.896970   4.266667
# Mean Dependency Distance                      2.180545   2.055879
# Node-to-Terminal-Node Ratio                   1.928909   1.964788
# Average Levenshtein Distance between POS      0.000000   0.000000
# Average Levenshtein Distance between deprel   0.000000   0.000000
# Average NP Length                             2.190909   2.048121
# Complex NP Ratio                              0.649758   0.601515
# Number of Combined Clauses                    1.254545   0.745455
# Number of Coordinate Clauses                  0.400000   0.169697
# Number of Subordinate Clauses                 0.854545   0.575758
# Coordinate to Combined Clause Ratio           0.276606   0.132303
# Subordinate to Combined Clause Ratio          0.523394   0.437394
# Coordinate to Subordinate Clause Ratio        0.172727   0.069697
# Coordinate Clause to Sentence Ratio           0.400000   0.169697
# Subordinate Clause to Sentence Ratio          0.854545   0.575758
# ROOT_ratio                                    0.532323   0.686869
# root_ratio                                    0.000000   0.000000
# acl_ratio                                     0.034848   0.024242
# acl:relcl_ratio                               0.022222   0.029293
# advcl_ratio                                   0.105556   0.062626
# advcl:relcl_ratio                             0.000000   0.000000
# ccomp_ratio                                   0.032323   0.037374
# csubj_ratio                                   0.011111   0.016162
# csubj:outer_ratio                             0.000000   0.000000
# nsubj:outer_ratio                             0.000000   0.000000
# parataxis_ratio                               0.013131   0.005051
# xcomp_ratio                                   0.104545   0.071212
# conj_ratio                                    0.143939   0.067172
# Distractors/Question                          3.000000   3.000000
#
#                                              true_distractors
# Number of Sentences                                  1.006024
# Number of Words                                     12.060241
# Number of Clauses                                    2.192771
# Number of T-Units                                    1.319277
# Mean Sentence Length                                11.996988
# Mean Clause Length                                   6.478133
# Mean T-Unit Length                                   9.642108
# Mean Number of Clauses per Sentence                  2.180723
# Mean Number of Clauses per T-Unit                    1.697771
# Mean Tree Depth                                      4.674699
# Median Tree Depth                                    4.674699
# Minimum Tree Depth                                   4.668675
# Maximum Tree Depth                                   4.680723
# Mean Dependency Distance                             2.346747
# Node-to-Terminal-Node Ratio                          1.954759
# Average Levenshtein Distance between POS             0.048193
# Average Levenshtein Distance between deprel          0.060241
# Average NP Length                                    2.174880
# Complex NP Ratio                                     0.623012
# Number of Combined Clauses                           1.186747
# Number of Coordinate Clauses                         0.313253
# Number of Subordinate Clauses                        0.873494
# Coordinate to Combined Clause Ratio                  0.162711
# Subordinate to Combined Clause Ratio                 0.457771
# Coordinate to Subordinate Clause Ratio               0.140000
# Coordinate Clause to Sentence Ratio                  0.313253
# Subordinate Clause to Sentence Ratio                 0.867470
# ROOT_ratio                                           0.618876
# root_ratio                                           0.000000
# acl_ratio                                            0.042972
# acl:relcl_ratio                                      0.024297
# advcl_ratio                                          0.077309
# advcl:relcl_ratio                                    0.000000
# ccomp_ratio                                          0.021486
# csubj_ratio                                          0.028313
# csubj:outer_ratio                                    0.000000
# nsubj:outer_ratio                                    0.000000
# parataxis_ratio                                      0.029819
# xcomp_ratio                                          0.086647
# conj_ratio                                           0.070281
# Distractors/Question                                 3.018182

# %%
for key, val in data_dict.items():
    print(key, len(val))
# Out:
# BartDG 55
# BartDG_PM 55
# BartDG_ANPM 55
# MuSeRC_GPT3 55
# MuSeRC_T5 55
# RuRace_GPT3 55
# RuRace_T5 55
# Deepseek 55
# ChatGPT4o 55
# true_distractors 55

# %%
averaged_table.T.to_excel(
    "../data/avg_syntaxcomp_metrics_spacy.xlsx", float_format="%.2f"
)

# %% [markdown]
# Let's build confidence intervals for the mean using the T-distribution technique:

# %%
## Compute averaged table
averaged_table_wconf = []

for key in data_with_syn_scores:
    df = pd.DataFrame(data_with_syn_scores[key])

    df = df.drop(
        [
            "distractor_set_id",
            "distractor_id",
            "distractor_text",
            "distractor_parse"
        ], axis="columns"
    )
    row = dict()
    row["source"] = key

    for key in df.columns:
        d = df[key]
        m, s, n = np.mean(d), np.std(d, ddof=1), len(d)  # Mean, SD, Size
        t = scipy.stats.t.ppf(0.975, df=n-1)  # t-value
        e = t * (s / np.sqrt(n))  # Margin

        row[key] = f"{m.__format__('.2f')} ± {e.__format__('.2f')}"
    
    row["D/Q"] = df["Number of Clauses"].notna().sum() / 55

    averaged_table_wconf.append(row)

averaged_table_wconf = pd.DataFrame(averaged_table_wconf).set_index("source")

# %%
table4 = averaged_table_wconf.T
table4
# Out:
# source                                            BartDG    BartDG_PM  \
# Number of Sentences                          1.04 ± 0.04  1.06 ± 0.05
# Number of Words                              7.93 ± 0.46  9.14 ± 0.56
# Number of Clauses                            1.47 ± 0.10  1.84 ± 0.14
# Number of T-Units                            1.14 ± 0.07  1.14 ± 0.07
# Mean Sentence Length                         7.80 ± 0.46  8.75 ± 0.48
# Mean Clause Length                           5.87 ± 0.33  5.63 ± 0.34
# Mean T-Unit Length                           7.25 ± 0.40  8.30 ± 0.45
# Mean Number of Clauses per Sentence          1.43 ± 0.10  1.75 ± 0.13
# Mean Number of Clauses per T-Unit            1.30 ± 0.07  1.65 ± 0.12
# Mean Tree Depth                              3.72 ± 0.13  3.96 ± 0.15
# Median Tree Depth                            3.71 ± 0.14  3.95 ± 0.15
# Minimum Tree Depth                           3.70 ± 0.14  3.92 ± 0.16
# Maximum Tree Depth                           3.74 ± 0.13  4.02 ± 0.15
# Mean Dependency Distance                     2.23 ± 0.08  2.18 ± 0.07
# Node-to-Terminal-Node Ratio                  1.92 ± 0.06  1.84 ± 0.05
# Average Levenshtein Distance between POS     0.07 ± 0.09  0.41 ± 0.36
# Average Levenshtein Distance between deprel  0.07 ± 0.08  0.43 ± 0.36
# Average NP Length                            2.21 ± 0.15  2.17 ± 0.15
# Complex NP Ratio                             0.67 ± 0.05  0.62 ± 0.04
# Number of Combined Clauses                   0.43 ± 0.10  0.78 ± 0.13
# Number of Coordinate Clauses                 0.10 ± 0.05  0.08 ± 0.04
# Number of Subordinate Clauses                0.33 ± 0.08  0.69 ± 0.12
# Coordinate to Combined Clause Ratio          0.08 ± 0.04  0.06 ± 0.03
# Subordinate to Combined Clause Ratio         0.29 ± 0.07  0.48 ± 0.07
# Coordinate to Subordinate Clause Ratio       0.05 ± 0.04  0.04 ± 0.03
# Coordinate Clause to Sentence Ratio          0.10 ± 0.05  0.08 ± 0.04
# Subordinate Clause to Sentence Ratio         0.33 ± 0.08  0.68 ± 0.12
# ROOT_ratio                                   0.81 ± 0.04  0.70 ± 0.04
# root_ratio                                   0.00 ± 0.00  0.00 ± 0.00
# acl_ratio                                    0.01 ± 0.01  0.06 ± 0.02
# acl:relcl_ratio                              0.04 ± 0.02  0.03 ± 0.02
# advcl_ratio                                  0.03 ± 0.02  0.05 ± 0.02
# advcl:relcl_ratio                            0.00 ± 0.00  0.00 ± 0.00
# ccomp_ratio                                  0.02 ± 0.01  0.05 ± 0.02
# csubj_ratio                                  0.01 ± 0.01  0.02 ± 0.01
# csubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# nsubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# parataxis_ratio                              0.01 ± 0.01  0.01 ± 0.01
# xcomp_ratio                                  0.04 ± 0.02  0.06 ± 0.02
# conj_ratio                                   0.03 ± 0.02  0.02 ± 0.01
# D/Q                                             3.018182     3.018182
#
# source                                       BartDG_ANPM  MuSeRC_GPT3  \
# Number of Sentences                          1.04 ± 0.04  1.01 ± 0.01
# Number of Words                              8.75 ± 0.49  5.32 ± 0.49
# Number of Clauses                            1.89 ± 0.15  1.53 ± 0.13
# Number of T-Units                            1.07 ± 0.05  1.14 ± 0.06
# Mean Sentence Length                         8.65 ± 0.49  5.28 ± 0.48
# Mean Clause Length                           5.27 ± 0.31  3.67 ± 0.27
# Mean T-Unit Length                           8.44 ± 0.48  4.78 ± 0.42
# Mean Number of Clauses per Sentence          1.86 ± 0.15  1.51 ± 0.12
# Mean Number of Clauses per T-Unit            1.80 ± 0.14  1.36 ± 0.10
# Mean Tree Depth                              4.07 ± 0.17  3.08 ± 0.16
# Median Tree Depth                            4.06 ± 0.17  3.08 ± 0.16
# Minimum Tree Depth                           4.05 ± 0.18  3.08 ± 0.16
# Maximum Tree Depth                           4.09 ± 0.17  3.08 ± 0.16
# Mean Dependency Distance                     2.12 ± 0.07  1.84 ± 0.09
# Node-to-Terminal-Node Ratio                  1.82 ± 0.05  1.79 ± 0.08
# Average Levenshtein Distance between POS     0.05 ± 0.07  0.06 ± 0.11
# Average Levenshtein Distance between deprel  0.05 ± 0.07  0.06 ± 0.11
# Average NP Length                            1.98 ± 0.14  1.68 ± 0.13
# Complex NP Ratio                             0.54 ± 0.05  0.44 ± 0.06
# Number of Combined Clauses                   0.86 ± 0.15  0.52 ± 0.12
# Number of Coordinate Clauses                 0.04 ± 0.03  0.13 ± 0.06
# Number of Subordinate Clauses                0.82 ± 0.14  0.39 ± 0.10
# Coordinate to Combined Clause Ratio          0.02 ± 0.02  0.09 ± 0.04
# Subordinate to Combined Clause Ratio         0.52 ± 0.08  0.29 ± 0.07
# Coordinate to Subordinate Clause Ratio       0.02 ± 0.02  0.04 ± 0.03
# Coordinate Clause to Sentence Ratio          0.04 ± 0.03  0.13 ± 0.06
# Subordinate Clause to Sentence Ratio         0.82 ± 0.14  0.39 ± 0.10
# ROOT_ratio                                   0.68 ± 0.05  0.79 ± 0.04
# root_ratio                                   0.00 ± 0.00  0.00 ± 0.00
# acl_ratio                                    0.02 ± 0.01  0.01 ± 0.01
# acl:relcl_ratio                              0.01 ± 0.01  0.00 ± 0.01
# advcl_ratio                                  0.08 ± 0.02  0.02 ± 0.01
# advcl:relcl_ratio                            0.00 ± 0.00  0.00 ± 0.00
# ccomp_ratio                                  0.10 ± 0.03  0.02 ± 0.01
# csubj_ratio                                  0.02 ± 0.01  0.01 ± 0.01
# csubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# nsubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# parataxis_ratio                              0.00 ± 0.01  0.02 ± 0.02
# xcomp_ratio                                  0.08 ± 0.02  0.10 ± 0.03
# conj_ratio                                   0.01 ± 0.01  0.03 ± 0.02
# D/Q                                             3.018182          2.8
#
# source                                         MuSeRC_T5  RuRace_GPT3  \
# Number of Sentences                          1.01 ± 0.02  1.00 ± 0.00
# Number of Words                              7.45 ± 0.89  9.64 ± 0.51
# Number of Clauses                            1.68 ± 0.19  1.80 ± 0.15
# Number of T-Units                            1.12 ± 0.07  1.10 ± 0.05
# Mean Sentence Length                         7.31 ± 0.82  9.64 ± 0.51
# Mean Clause Length                           4.81 ± 0.55  6.20 ± 0.40
# Mean T-Unit Length                           6.76 ± 0.76  9.10 ± 0.52
# Mean Number of Clauses per Sentence          1.65 ± 0.18  1.80 ± 0.15
# Mean Number of Clauses per T-Unit            1.51 ± 0.15  1.66 ± 0.13
# Mean Tree Depth                              3.74 ± 0.25  4.12 ± 0.16
# Median Tree Depth                            3.74 ± 0.25  4.12 ± 0.16
# Minimum Tree Depth                           3.73 ± 0.25  4.12 ± 0.16
# Maximum Tree Depth                           3.74 ± 0.25  4.12 ± 0.16
# Mean Dependency Distance                     2.02 ± 0.13  2.31 ± 0.08
# Node-to-Terminal-Node Ratio                  1.92 ± 0.09  1.86 ± 0.06
# Average Levenshtein Distance between POS     0.09 ± 0.18  0.00 ± 0.00
# Average Levenshtein Distance between deprel  0.13 ± 0.25  0.00 ± 0.00
# Average NP Length                            1.71 ± 0.14  2.10 ± 0.13
# Complex NP Ratio                             0.47 ± 0.07  0.59 ± 0.05
# Number of Combined Clauses                   0.67 ± 0.18  0.80 ± 0.15
# Number of Coordinate Clauses                 0.11 ± 0.07  0.10 ± 0.05
# Number of Subordinate Clauses                0.56 ± 0.17  0.70 ± 0.13
# Coordinate to Combined Clause Ratio          0.07 ± 0.05  0.07 ± 0.04
# Subordinate to Combined Clause Ratio         0.36 ± 0.10  0.46 ± 0.08
# Coordinate to Subordinate Clause Ratio       0.05 ± 0.04  0.04 ± 0.03
# Coordinate Clause to Sentence Ratio          0.11 ± 0.07  0.10 ± 0.05
# Subordinate Clause to Sentence Ratio         0.55 ± 0.16  0.70 ± 0.13
# ROOT_ratio                                   0.75 ± 0.06  0.70 ± 0.05
# root_ratio                                   0.00 ± 0.00  0.00 ± 0.00
# acl_ratio                                    0.01 ± 0.01  0.04 ± 0.02
# acl:relcl_ratio                              0.02 ± 0.02  0.03 ± 0.02
# advcl_ratio                                  0.03 ± 0.02  0.07 ± 0.03
# advcl:relcl_ratio                            0.00 ± 0.00  0.00 ± 0.00
# ccomp_ratio                                  0.04 ± 0.03  0.04 ± 0.02
# csubj_ratio                                  0.01 ± 0.01  0.01 ± 0.01
# csubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# nsubj:outer_ratio                            0.00 ± 0.00  0.00 ± 0.00
# parataxis_ratio                              0.01 ± 0.01  0.01 ± 0.01
# xcomp_ratio                                  0.10 ± 0.04  0.07 ± 0.02
# conj_ratio                                   0.03 ± 0.02  0.03 ± 0.02
# D/Q                                             1.545455     2.836364
#
# source                                         RuRace_T5      Deepseek  \
# Number of Sentences                          1.00 ± 0.00   1.00 ± 0.00
# Number of Words                              8.69 ± 0.45  13.04 ± 0.44
# Number of Clauses                            1.86 ± 0.12   2.25 ± 0.14
# Number of T-Units                            1.14 ± 0.05   1.40 ± 0.08
# Mean Sentence Length                         8.69 ± 0.45  13.04 ± 0.44
# Mean Clause Length                           5.27 ± 0.37   6.67 ± 0.44
# Mean T-Unit Length                           7.97 ± 0.45  10.39 ± 0.59
# Mean Number of Clauses per Sentence          1.86 ± 0.12   2.25 ± 0.14
# Mean Number of Clauses per T-Unit            1.67 ± 0.11   1.73 ± 0.12
# Mean Tree Depth                              3.82 ± 0.14   4.90 ± 0.17
# Median Tree Depth                            3.82 ± 0.14   4.90 ± 0.17
# Minimum Tree Depth                           3.82 ± 0.14   4.90 ± 0.17
# Maximum Tree Depth                           3.82 ± 0.14   4.90 ± 0.17
# Mean Dependency Distance                     2.29 ± 0.08   2.18 ± 0.05
# Node-to-Terminal-Node Ratio                  1.82 ± 0.06   1.93 ± 0.05
# Average Levenshtein Distance between POS     0.00 ± 0.00   0.00 ± 0.00
# Average Levenshtein Distance between deprel  0.00 ± 0.00   0.00 ± 0.00
# Average NP Length                            1.91 ± 0.14   2.19 ± 0.10
# Complex NP Ratio                             0.52 ± 0.05   0.65 ± 0.04
# Number of Combined Clauses                   0.86 ± 0.12   1.25 ± 0.14
# Number of Coordinate Clauses                 0.14 ± 0.05   0.40 ± 0.08
# Number of Subordinate Clauses                0.71 ± 0.11   0.85 ± 0.13
# Coordinate to Combined Clause Ratio          0.11 ± 0.04   0.28 ± 0.06
# Subordinate to Combined Clause Ratio         0.52 ± 0.08   0.52 ± 0.07
# Coordinate to Subordinate Clause Ratio       0.06 ± 0.04   0.17 ± 0.06
# Coordinate Clause to Sentence Ratio          0.14 ± 0.05   0.40 ± 0.08
# Subordinate Clause to Sentence Ratio         0.71 ± 0.11   0.85 ± 0.13
# ROOT_ratio                                   0.65 ± 0.04   0.53 ± 0.04
# root_ratio                                   0.00 ± 0.00   0.00 ± 0.00
# acl_ratio                                    0.02 ± 0.01   0.03 ± 0.02
# acl:relcl_ratio                              0.04 ± 0.02   0.02 ± 0.01
# advcl_ratio                                  0.08 ± 0.03   0.11 ± 0.03
# advcl:relcl_ratio                            0.00 ± 0.00   0.00 ± 0.00
# ccomp_ratio                                  0.05 ± 0.02   0.03 ± 0.02
# csubj_ratio                                  0.01 ± 0.01   0.01 ± 0.01
# csubj:outer_ratio                            0.00 ± 0.00   0.00 ± 0.00
# nsubj:outer_ratio                            0.00 ± 0.00   0.00 ± 0.00
# parataxis_ratio                              0.04 ± 0.02   0.01 ± 0.01
# xcomp_ratio                                  0.09 ± 0.03   0.10 ± 0.03
# conj_ratio                                   0.02 ± 0.02   0.14 ± 0.03
# D/Q                                             2.909091           3.0
#
# source                                         ChatGPT4o true_distractors
# Number of Sentences                          1.00 ± 0.00      1.01 ± 0.01
# Number of Words                              9.46 ± 0.37     12.06 ± 0.76
# Number of Clauses                            1.75 ± 0.12      2.19 ± 0.19
# Number of T-Units                            1.17 ± 0.06      1.32 ± 0.09
# Mean Sentence Length                         9.46 ± 0.37     12.00 ± 0.75
# Mean Clause Length                           6.13 ± 0.34      6.48 ± 0.44
# Mean T-Unit Length                           8.47 ± 0.37      9.64 ± 0.56
# Mean Number of Clauses per Sentence          1.75 ± 0.12      2.18 ± 0.19
# Mean Number of Clauses per T-Unit            1.54 ± 0.10      1.70 ± 0.13
# Mean Tree Depth                              4.27 ± 0.13      4.67 ± 0.19
# Median Tree Depth                            4.27 ± 0.13      4.67 ± 0.19
# Minimum Tree Depth                           4.27 ± 0.13      4.67 ± 0.19
# Maximum Tree Depth                           4.27 ± 0.13      4.68 ± 0.19
# Mean Dependency Distance                     2.06 ± 0.06      2.35 ± 0.08
# Node-to-Terminal-Node Ratio                  1.96 ± 0.05      1.95 ± 0.05
# Average Levenshtein Distance between POS     0.00 ± 0.00      0.05 ± 0.10
# Average Levenshtein Distance between deprel  0.00 ± 0.00      0.06 ± 0.12
# Average NP Length                            2.05 ± 0.10      2.17 ± 0.13
# Complex NP Ratio                             0.60 ± 0.04      0.62 ± 0.04
# Number of Combined Clauses                   0.75 ± 0.12      1.19 ± 0.19
# Number of Coordinate Clauses                 0.17 ± 0.06      0.31 ± 0.09
# Number of Subordinate Clauses                0.58 ± 0.10      0.87 ± 0.16
# Coordinate to Combined Clause Ratio          0.13 ± 0.05      0.16 ± 0.05
# Subordinate to Combined Clause Ratio         0.44 ± 0.07      0.46 ± 0.07
# Coordinate to Subordinate Clause Ratio       0.07 ± 0.04      0.14 ± 0.05
# Coordinate Clause to Sentence Ratio          0.17 ± 0.06      0.31 ± 0.09
# Subordinate Clause to Sentence Ratio         0.58 ± 0.10      0.87 ± 0.16
# ROOT_ratio                                   0.69 ± 0.04      0.62 ± 0.05
# root_ratio                                   0.00 ± 0.00      0.00 ± 0.00
# acl_ratio                                    0.02 ± 0.02      0.04 ± 0.02
# acl:relcl_ratio                              0.03 ± 0.02      0.02 ± 0.01
# advcl_ratio                                  0.06 ± 0.02      0.08 ± 0.02
# advcl:relcl_ratio                            0.00 ± 0.00      0.00 ± 0.00
# ccomp_ratio                                  0.04 ± 0.02      0.02 ± 0.01
# csubj_ratio                                  0.02 ± 0.01      0.03 ± 0.02
# csubj:outer_ratio                            0.00 ± 0.00      0.00 ± 0.00
# nsubj:outer_ratio                            0.00 ± 0.00      0.00 ± 0.00
# parataxis_ratio                              0.01 ± 0.01      0.03 ± 0.02
# xcomp_ratio                                  0.07 ± 0.02      0.09 ± 0.03
# conj_ratio                                   0.07 ± 0.02      0.07 ± 0.02
# D/Q                                                  3.0         3.018182

# %%
table4.to_excel("../data/avg_syntaxcomp_metrics_spacy_CI.xlsx")
table4.to_excel("../data/table4.xlsx")

# %% [markdown]
# Ans using the Bootstrap technique:

# %%
## Compute averaged table
averaged_table_wconf_ = []

for key in data_with_syn_scores:
    df = pd.DataFrame(data_with_syn_scores[key])

    df = df.drop(
        [
            "distractor_set_id",
            "distractor_id",
            "distractor_text",
            "distractor_parse"
        ], axis="columns"
    )
    row = dict()
    row["source"] = key

    for key in df.columns:
        bootstrap_result = scipy.stats.bootstrap((df[key].dropna(), ), np.mean, method="basic", rng=42)
        m = df[key].mean()
        l = bootstrap_result.confidence_interval.low
        h = bootstrap_result.confidence_interval.high

        row[key] = f"{l.__format__('.2f')} < {m.__format__('.2f')} > {h.__format__('.2f')}"

    averaged_table_wconf_.append(row)

averaged_table_wconf_ = pd.DataFrame(averaged_table_wconf_).set_index("source")

# %%
averaged_table_wconf_.T
# Out:
# source                                                    BartDG  \
# Number of Sentences                           0.99 < 1.04 > 1.07
# Number of Words                               7.46 < 7.93 > 8.39
# Number of Clauses                             1.36 < 1.47 > 1.57
# Number of T-Units                             1.07 < 1.14 > 1.20
# Mean Sentence Length                          7.35 < 7.80 > 8.24
# Mean Clause Length                            5.54 < 5.87 > 6.19
# Mean T-Unit Length                            6.86 < 7.25 > 7.64
# Mean Number of Clauses per Sentence           1.33 < 1.43 > 1.52
# Mean Number of Clauses per T-Unit             1.23 < 1.30 > 1.37
# Mean Tree Depth                               3.59 < 3.72 > 3.85
# Median Tree Depth                             3.58 < 3.71 > 3.85
# Minimum Tree Depth                            3.57 < 3.70 > 3.84
# Maximum Tree Depth                            3.61 < 3.74 > 3.87
# Mean Dependency Distance                      2.15 < 2.23 > 2.31
# Node-to-Terminal-Node Ratio                   1.86 < 1.92 > 1.99
# Average Levenshtein Distance between POS     -0.02 < 0.07 > 0.14
# Average Levenshtein Distance between deprel  -0.02 < 0.07 > 0.14
# Average NP Length                             2.05 < 2.21 > 2.35
# Complex NP Ratio                              0.62 < 0.67 > 0.72
# Number of Combined Clauses                    0.33 < 0.43 > 0.53
# Number of Coordinate Clauses                  0.05 < 0.10 > 0.15
# Number of Subordinate Clauses                 0.25 < 0.33 > 0.40
# Coordinate to Combined Clause Ratio           0.04 < 0.08 > 0.11
# Subordinate to Combined Clause Ratio          0.22 < 0.29 > 0.36
# Coordinate to Subordinate Clause Ratio        0.01 < 0.05 > 0.08
# Coordinate Clause to Sentence Ratio           0.05 < 0.10 > 0.15
# Subordinate Clause to Sentence Ratio          0.25 < 0.33 > 0.40
# ROOT_ratio                                    0.77 < 0.81 > 0.85
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                    -0.00 < 0.01 > 0.02
# acl:relcl_ratio                               0.02 < 0.04 > 0.05
# advcl_ratio                                   0.02 < 0.03 > 0.05
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.00 < 0.02 > 0.03
# csubj_ratio                                  -0.00 < 0.01 > 0.02
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                              -0.00 < 0.01 > 0.02
# xcomp_ratio                                   0.02 < 0.04 > 0.06
# conj_ratio                                    0.01 < 0.03 > 0.05
#
# source                                                BartDG_PM  \
# Number of Sentences                          1.01 < 1.06 > 1.10
# Number of Words                              8.57 < 9.14 > 9.69
# Number of Clauses                            1.69 < 1.84 > 1.98
# Number of T-Units                            1.07 < 1.14 > 1.20
# Mean Sentence Length                         8.27 < 8.75 > 9.23
# Mean Clause Length                           5.28 < 5.63 > 5.97
# Mean T-Unit Length                           7.85 < 8.30 > 8.75
# Mean Number of Clauses per Sentence          1.62 < 1.75 > 1.88
# Mean Number of Clauses per T-Unit            1.53 < 1.65 > 1.76
# Mean Tree Depth                              3.82 < 3.96 > 4.11
# Median Tree Depth                            3.80 < 3.95 > 4.10
# Minimum Tree Depth                           3.76 < 3.92 > 4.07
# Maximum Tree Depth                           3.87 < 4.02 > 4.16
# Mean Dependency Distance                     2.11 < 2.18 > 2.25
# Node-to-Terminal-Node Ratio                  1.79 < 1.84 > 1.89
# Average Levenshtein Distance between POS     0.02 < 0.41 > 0.72
# Average Levenshtein Distance between deprel  0.03 < 0.43 > 0.73
# Average NP Length                            2.01 < 2.17 > 2.32
# Complex NP Ratio                             0.58 < 0.62 > 0.67
# Number of Combined Clauses                   0.64 < 0.78 > 0.90
# Number of Coordinate Clauses                 0.04 < 0.08 > 0.13
# Number of Subordinate Clauses                0.57 < 0.69 > 0.81
# Coordinate to Combined Clause Ratio          0.02 < 0.06 > 0.09
# Subordinate to Combined Clause Ratio         0.41 < 0.48 > 0.56
# Coordinate to Subordinate Clause Ratio       0.01 < 0.04 > 0.07
# Coordinate Clause to Sentence Ratio          0.04 < 0.08 > 0.11
# Subordinate Clause to Sentence Ratio         0.55 < 0.68 > 0.80
# ROOT_ratio                                   0.66 < 0.70 > 0.74
# root_ratio                                   0.00 < 0.00 > 0.00
# acl_ratio                                    0.03 < 0.06 > 0.08
# acl:relcl_ratio                              0.01 < 0.03 > 0.05
# advcl_ratio                                  0.03 < 0.05 > 0.07
# advcl:relcl_ratio                            0.00 < 0.00 > 0.00
# ccomp_ratio                                  0.03 < 0.05 > 0.07
# csubj_ratio                                  0.01 < 0.02 > 0.03
# csubj:outer_ratio                            0.00 < 0.00 > 0.00
# nsubj:outer_ratio                            0.00 < 0.00 > 0.00
# parataxis_ratio                              0.00 < 0.01 > 0.02
# xcomp_ratio                                  0.03 < 0.06 > 0.08
# conj_ratio                                   0.00 < 0.02 > 0.03
#
# source                                               BartDG_ANPM  \
# Number of Sentences                           0.99 < 1.04 > 1.07
# Number of Words                               8.27 < 8.75 > 9.23
# Number of Clauses                             1.74 < 1.89 > 2.04
# Number of T-Units                             1.02 < 1.07 > 1.11
# Mean Sentence Length                          8.16 < 8.65 > 9.14
# Mean Clause Length                            4.96 < 5.27 > 5.58
# Mean T-Unit Length                            7.96 < 8.44 > 8.92
# Mean Number of Clauses per Sentence           1.71 < 1.86 > 2.00
# Mean Number of Clauses per T-Unit             1.66 < 1.80 > 1.94
# Mean Tree Depth                               3.90 < 4.07 > 4.23
# Median Tree Depth                             3.89 < 4.06 > 4.23
# Minimum Tree Depth                            3.88 < 4.05 > 4.22
# Maximum Tree Depth                            3.92 < 4.09 > 4.25
# Mean Dependency Distance                      2.04 < 2.12 > 2.19
# Node-to-Terminal-Node Ratio                   1.77 < 1.82 > 1.87
# Average Levenshtein Distance between POS     -0.03 < 0.05 > 0.10
# Average Levenshtein Distance between deprel  -0.03 < 0.05 > 0.11
# Average NP Length                             1.84 < 1.98 > 2.11
# Complex NP Ratio                              0.49 < 0.54 > 0.59
# Number of Combined Clauses                    0.71 < 0.86 > 1.00
# Number of Coordinate Clauses                  0.01 < 0.04 > 0.06
# Number of Subordinate Clauses                 0.67 < 0.82 > 0.96
# Coordinate to Combined Clause Ratio           0.00 < 0.02 > 0.04
# Subordinate to Combined Clause Ratio          0.44 < 0.52 > 0.60
# Coordinate to Subordinate Clause Ratio       -0.00 < 0.02 > 0.03
# Coordinate Clause to Sentence Ratio           0.01 < 0.04 > 0.06
# Subordinate Clause to Sentence Ratio          0.67 < 0.82 > 0.96
# ROOT_ratio                                    0.64 < 0.68 > 0.73
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                     0.00 < 0.02 > 0.03
# acl:relcl_ratio                               0.00 < 0.01 > 0.02
# advcl_ratio                                   0.05 < 0.08 > 0.10
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.07 < 0.10 > 0.12
# csubj_ratio                                   0.01 < 0.02 > 0.03
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                              -0.00 < 0.00 > 0.01
# xcomp_ratio                                   0.05 < 0.08 > 0.10
# conj_ratio                                    0.00 < 0.01 > 0.02
#
# source                                               MuSeRC_GPT3  \
# Number of Sentences                           0.99 < 1.01 > 1.01
# Number of Words                               4.82 < 5.32 > 5.79
# Number of Clauses                             1.40 < 1.53 > 1.65
# Number of T-Units                             1.06 < 1.14 > 1.19
# Mean Sentence Length                          4.79 < 5.28 > 5.74
# Mean Clause Length                            3.39 < 3.67 > 3.94
# Mean T-Unit Length                            4.34 < 4.78 > 5.18
# Mean Number of Clauses per Sentence           1.38 < 1.51 > 1.63
# Mean Number of Clauses per T-Unit             1.26 < 1.36 > 1.46
# Mean Tree Depth                               2.92 < 3.08 > 3.24
# Median Tree Depth                             2.92 < 3.08 > 3.24
# Minimum Tree Depth                            2.91 < 3.08 > 3.24
# Maximum Tree Depth                            2.92 < 3.08 > 3.25
# Mean Dependency Distance                      1.75 < 1.84 > 1.92
# Node-to-Terminal-Node Ratio                   1.71 < 1.79 > 1.87
# Average Levenshtein Distance between POS     -0.06 < 0.06 > 0.12
# Average Levenshtein Distance between deprel  -0.06 < 0.06 > 0.12
# Average NP Length                             1.55 < 1.68 > 1.81
# Complex NP Ratio                              0.38 < 0.44 > 0.50
# Number of Combined Clauses                    0.39 < 0.52 > 0.64
# Number of Coordinate Clauses                  0.06 < 0.13 > 0.19
# Number of Subordinate Clauses                 0.28 < 0.39 > 0.49
# Coordinate to Combined Clause Ratio           0.04 < 0.09 > 0.13
# Subordinate to Combined Clause Ratio          0.22 < 0.29 > 0.35
# Coordinate to Subordinate Clause Ratio        0.00 < 0.04 > 0.07
# Coordinate Clause to Sentence Ratio           0.06 < 0.13 > 0.18
# Subordinate Clause to Sentence Ratio          0.28 < 0.39 > 0.49
# ROOT_ratio                                    0.75 < 0.79 > 0.84
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                    -0.00 < 0.01 > 0.02
# acl:relcl_ratio                              -0.00 < 0.00 > 0.01
# advcl_ratio                                   0.00 < 0.02 > 0.03
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.00 < 0.02 > 0.03
# csubj_ratio                                  -0.00 < 0.01 > 0.01
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                               0.00 < 0.02 > 0.04
# xcomp_ratio                                   0.07 < 0.10 > 0.13
# conj_ratio                                    0.01 < 0.03 > 0.04
#
# source                                                 MuSeRC_T5  \
# Number of Sentences                           0.99 < 1.01 > 1.02
# Number of Words                               6.54 < 7.45 > 8.31
# Number of Clauses                             1.48 < 1.68 > 1.87
# Number of T-Units                             1.05 < 1.12 > 1.18
# Mean Sentence Length                          6.48 < 7.31 > 8.11
# Mean Clause Length                            4.24 < 4.81 > 5.33
# Mean T-Unit Length                            5.99 < 6.76 > 7.50
# Mean Number of Clauses per Sentence           1.47 < 1.65 > 1.83
# Mean Number of Clauses per T-Unit             1.35 < 1.51 > 1.65
# Mean Tree Depth                               3.48 < 3.74 > 3.98
# Median Tree Depth                             3.48 < 3.74 > 3.98
# Minimum Tree Depth                            3.48 < 3.73 > 3.98
# Maximum Tree Depth                            3.49 < 3.74 > 3.99
# Mean Dependency Distance                      1.89 < 2.02 > 2.14
# Node-to-Terminal-Node Ratio                   1.83 < 1.92 > 2.01
# Average Levenshtein Distance between POS     -0.09 < 0.09 > 0.19
# Average Levenshtein Distance between deprel  -0.13 < 0.13 > 0.26
# Average NP Length                             1.56 < 1.71 > 1.84
# Complex NP Ratio                              0.40 < 0.47 > 0.54
# Number of Combined Clauses                    0.48 < 0.67 > 0.85
# Number of Coordinate Clauses                  0.04 < 0.11 > 0.16
# Number of Subordinate Clauses                 0.39 < 0.56 > 0.73
# Coordinate to Combined Clause Ratio           0.02 < 0.07 > 0.12
# Subordinate to Combined Clause Ratio          0.26 < 0.36 > 0.46
# Coordinate to Subordinate Clause Ratio        0.00 < 0.05 > 0.08
# Coordinate Clause to Sentence Ratio           0.04 < 0.11 > 0.16
# Subordinate Clause to Sentence Ratio          0.38 < 0.55 > 0.70
# ROOT_ratio                                    0.69 < 0.75 > 0.81
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                    -0.00 < 0.01 > 0.02
# acl:relcl_ratio                               0.00 < 0.02 > 0.04
# advcl_ratio                                   0.01 < 0.03 > 0.04
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.01 < 0.04 > 0.07
# csubj_ratio                                  -0.00 < 0.01 > 0.02
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                              -0.01 < 0.01 > 0.02
# xcomp_ratio                                   0.06 < 0.10 > 0.13
# conj_ratio                                    0.01 < 0.03 > 0.05
#
# source                                               RuRace_GPT3  \
# Number of Sentences                           1.00 < 1.00 > 1.00
# Number of Words                              9.12 < 9.64 > 10.13
# Number of Clauses                             1.65 < 1.80 > 1.94
# Number of T-Units                             1.05 < 1.10 > 1.15
# Mean Sentence Length                         9.12 < 9.64 > 10.13
# Mean Clause Length                            5.79 < 6.20 > 6.58
# Mean T-Unit Length                            8.57 < 9.10 > 9.60
# Mean Number of Clauses per Sentence           1.65 < 1.80 > 1.94
# Mean Number of Clauses per T-Unit             1.53 < 1.66 > 1.78
# Mean Tree Depth                               3.96 < 4.12 > 4.28
# Median Tree Depth                             3.96 < 4.12 > 4.28
# Minimum Tree Depth                            3.96 < 4.12 > 4.28
# Maximum Tree Depth                            3.96 < 4.12 > 4.28
# Mean Dependency Distance                      2.23 < 2.31 > 2.39
# Node-to-Terminal-Node Ratio                   1.81 < 1.86 > 1.92
# Average Levenshtein Distance between POS      0.00 < 0.00 > 0.00
# Average Levenshtein Distance between deprel   0.00 < 0.00 > 0.00
# Average NP Length                             1.97 < 2.10 > 2.23
# Complex NP Ratio                              0.55 < 0.59 > 0.64
# Number of Combined Clauses                    0.65 < 0.80 > 0.94
# Number of Coordinate Clauses                  0.05 < 0.10 > 0.15
# Number of Subordinate Clauses                 0.56 < 0.70 > 0.83
# Coordinate to Combined Clause Ratio           0.03 < 0.07 > 0.10
# Subordinate to Combined Clause Ratio          0.38 < 0.46 > 0.53
# Coordinate to Subordinate Clause Ratio        0.01 < 0.04 > 0.07
# Coordinate Clause to Sentence Ratio           0.05 < 0.10 > 0.15
# Subordinate Clause to Sentence Ratio          0.56 < 0.70 > 0.83
# ROOT_ratio                                    0.65 < 0.70 > 0.74
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                     0.02 < 0.04 > 0.05
# acl:relcl_ratio                               0.02 < 0.03 > 0.05
# advcl_ratio                                   0.04 < 0.07 > 0.10
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.02 < 0.04 > 0.07
# csubj_ratio                                  -0.00 < 0.01 > 0.01
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                              -0.00 < 0.01 > 0.02
# xcomp_ratio                                   0.05 < 0.07 > 0.10
# conj_ratio                                    0.01 < 0.03 > 0.05
#
# source                                                RuRace_T5  \
# Number of Sentences                          1.00 < 1.00 > 1.00
# Number of Words                              8.24 < 8.69 > 9.14
# Number of Clauses                            1.74 < 1.86 > 1.97
# Number of T-Units                            1.09 < 1.14 > 1.19
# Mean Sentence Length                         8.24 < 8.69 > 9.14
# Mean Clause Length                           4.91 < 5.27 > 5.63
# Mean T-Unit Length                           7.52 < 7.97 > 8.42
# Mean Number of Clauses per Sentence          1.74 < 1.86 > 1.97
# Mean Number of Clauses per T-Unit            1.56 < 1.67 > 1.78
# Mean Tree Depth                              3.68 < 3.82 > 3.96
# Median Tree Depth                            3.68 < 3.82 > 3.96
# Minimum Tree Depth                           3.68 < 3.82 > 3.96
# Maximum Tree Depth                           3.68 < 3.82 > 3.96
# Mean Dependency Distance                     2.21 < 2.29 > 2.38
# Node-to-Terminal-Node Ratio                  1.76 < 1.82 > 1.88
# Average Levenshtein Distance between POS     0.00 < 0.00 > 0.00
# Average Levenshtein Distance between deprel  0.00 < 0.00 > 0.00
# Average NP Length                            1.77 < 1.91 > 2.04
# Complex NP Ratio                             0.47 < 0.52 > 0.58
# Number of Combined Clauses                   0.74 < 0.86 > 0.97
# Number of Coordinate Clauses                 0.09 < 0.14 > 0.19
# Number of Subordinate Clauses                0.60 < 0.71 > 0.83
# Coordinate to Combined Clause Ratio          0.06 < 0.11 > 0.15
# Subordinate to Combined Clause Ratio         0.45 < 0.52 > 0.60
# Coordinate to Subordinate Clause Ratio       0.02 < 0.06 > 0.10
# Coordinate Clause to Sentence Ratio          0.09 < 0.14 > 0.19
# Subordinate Clause to Sentence Ratio         0.60 < 0.71 > 0.83
# ROOT_ratio                                   0.60 < 0.65 > 0.69
# root_ratio                                   0.00 < 0.00 > 0.00
# acl_ratio                                    0.00 < 0.02 > 0.03
# acl:relcl_ratio                              0.02 < 0.04 > 0.05
# advcl_ratio                                  0.06 < 0.08 > 0.11
# advcl:relcl_ratio                            0.00 < 0.00 > 0.00
# ccomp_ratio                                  0.03 < 0.05 > 0.07
# csubj_ratio                                  0.00 < 0.01 > 0.02
# csubj:outer_ratio                            0.00 < 0.00 > 0.00
# nsubj:outer_ratio                            0.00 < 0.00 > 0.00
# parataxis_ratio                              0.02 < 0.04 > 0.05
# xcomp_ratio                                  0.06 < 0.09 > 0.12
# conj_ratio                                   0.01 < 0.02 > 0.04
#
# source                                                    Deepseek  \
# Number of Sentences                             1.00 < 1.00 > 1.00
# Number of Words                              12.59 < 13.04 > 13.47
# Number of Clauses                               2.12 < 2.25 > 2.39
# Number of T-Units                               1.32 < 1.40 > 1.48
# Mean Sentence Length                         12.59 < 13.04 > 13.47
# Mean Clause Length                              6.23 < 6.67 > 7.09
# Mean T-Unit Length                            9.78 < 10.39 > 10.96
# Mean Number of Clauses per Sentence             2.12 < 2.25 > 2.39
# Mean Number of Clauses per T-Unit               1.60 < 1.73 > 1.85
# Mean Tree Depth                                 4.73 < 4.90 > 5.05
# Median Tree Depth                               4.73 < 4.90 > 5.05
# Minimum Tree Depth                              4.73 < 4.90 > 5.05
# Maximum Tree Depth                              4.73 < 4.90 > 5.05
# Mean Dependency Distance                        2.13 < 2.18 > 2.23
# Node-to-Terminal-Node Ratio                     1.87 < 1.93 > 1.98
# Average Levenshtein Distance between POS        0.00 < 0.00 > 0.00
# Average Levenshtein Distance between deprel     0.00 < 0.00 > 0.00
# Average NP Length                               2.09 < 2.19 > 2.29
# Complex NP Ratio                                0.61 < 0.65 > 0.69
# Number of Combined Clauses                      1.12 < 1.25 > 1.39
# Number of Coordinate Clauses                    0.32 < 0.40 > 0.48
# Number of Subordinate Clauses                   0.73 < 0.85 > 0.98
# Coordinate to Combined Clause Ratio             0.22 < 0.28 > 0.34
# Subordinate to Combined Clause Ratio            0.45 < 0.52 > 0.59
# Coordinate to Subordinate Clause Ratio          0.11 < 0.17 > 0.23
# Coordinate Clause to Sentence Ratio             0.32 < 0.40 > 0.48
# Subordinate Clause to Sentence Ratio            0.73 < 0.85 > 0.98
# ROOT_ratio                                      0.49 < 0.53 > 0.57
# root_ratio                                      0.00 < 0.00 > 0.00
# acl_ratio                                       0.02 < 0.03 > 0.05
# acl:relcl_ratio                                 0.01 < 0.02 > 0.04
# advcl_ratio                                     0.08 < 0.11 > 0.13
# advcl:relcl_ratio                               0.00 < 0.00 > 0.00
# ccomp_ratio                                     0.02 < 0.03 > 0.05
# csubj_ratio                                     0.00 < 0.01 > 0.02
# csubj:outer_ratio                               0.00 < 0.00 > 0.00
# nsubj:outer_ratio                               0.00 < 0.00 > 0.00
# parataxis_ratio                                 0.00 < 0.01 > 0.02
# xcomp_ratio                                     0.08 < 0.10 > 0.13
# conj_ratio                                      0.11 < 0.14 > 0.17
#
# source                                                 ChatGPT4o  \
# Number of Sentences                           1.00 < 1.00 > 1.00
# Number of Words                               9.08 < 9.46 > 9.82
# Number of Clauses                             1.63 < 1.75 > 1.85
# Number of T-Units                             1.11 < 1.17 > 1.22
# Mean Sentence Length                          9.08 < 9.46 > 9.82
# Mean Clause Length                            5.79 < 6.13 > 6.46
# Mean T-Unit Length                            8.10 < 8.47 > 8.84
# Mean Number of Clauses per Sentence           1.63 < 1.75 > 1.85
# Mean Number of Clauses per T-Unit             1.43 < 1.54 > 1.64
# Mean Tree Depth                               4.13 < 4.27 > 4.39
# Median Tree Depth                             4.13 < 4.27 > 4.39
# Minimum Tree Depth                            4.13 < 4.27 > 4.39
# Maximum Tree Depth                            4.13 < 4.27 > 4.39
# Mean Dependency Distance                      2.00 < 2.06 > 2.11
# Node-to-Terminal-Node Ratio                   1.91 < 1.96 > 2.01
# Average Levenshtein Distance between POS      0.00 < 0.00 > 0.00
# Average Levenshtein Distance between deprel   0.00 < 0.00 > 0.00
# Average NP Length                             1.94 < 2.05 > 2.15
# Complex NP Ratio                              0.56 < 0.60 > 0.64
# Number of Combined Clauses                    0.63 < 0.75 > 0.85
# Number of Coordinate Clauses                  0.11 < 0.17 > 0.22
# Number of Subordinate Clauses                 0.47 < 0.58 > 0.68
# Coordinate to Combined Clause Ratio           0.08 < 0.13 > 0.18
# Subordinate to Combined Clause Ratio          0.36 < 0.44 > 0.51
# Coordinate to Subordinate Clause Ratio        0.03 < 0.07 > 0.11
# Coordinate Clause to Sentence Ratio           0.11 < 0.17 > 0.22
# Subordinate Clause to Sentence Ratio          0.47 < 0.58 > 0.68
# ROOT_ratio                                    0.64 < 0.69 > 0.73
# root_ratio                                    0.00 < 0.00 > 0.00
# acl_ratio                                     0.01 < 0.02 > 0.04
# acl:relcl_ratio                               0.01 < 0.03 > 0.05
# advcl_ratio                                   0.04 < 0.06 > 0.09
# advcl:relcl_ratio                             0.00 < 0.00 > 0.00
# ccomp_ratio                                   0.02 < 0.04 > 0.05
# csubj_ratio                                   0.00 < 0.02 > 0.03
# csubj:outer_ratio                             0.00 < 0.00 > 0.00
# nsubj:outer_ratio                             0.00 < 0.00 > 0.00
# parataxis_ratio                              -0.00 < 0.01 > 0.01
# xcomp_ratio                                   0.05 < 0.07 > 0.09
# conj_ratio                                    0.04 < 0.07 > 0.09
#
# source                                            true_distractors
# Number of Sentences                             0.99 < 1.01 > 1.01
# Number of Words                              11.31 < 12.06 > 12.79
# Number of Clauses                               2.00 < 2.19 > 2.39
# Number of T-Units                               1.23 < 1.32 > 1.40
# Mean Sentence Length                         11.25 < 12.00 > 12.71
# Mean Clause Length                              6.04 < 6.48 > 6.90
# Mean T-Unit Length                             9.08 < 9.64 > 10.17
# Mean Number of Clauses per Sentence             1.99 < 2.18 > 2.37
# Mean Number of Clauses per T-Unit               1.56 < 1.70 > 1.83
# Mean Tree Depth                                 4.48 < 4.67 > 4.86
# Median Tree Depth                               4.48 < 4.67 > 4.86
# Minimum Tree Depth                              4.48 < 4.67 > 4.85
# Maximum Tree Depth                              4.49 < 4.68 > 4.86
# Mean Dependency Distance                        2.26 < 2.35 > 2.43
# Node-to-Terminal-Node Ratio                     1.90 < 1.95 > 2.00
# Average Levenshtein Distance between POS       -0.05 < 0.05 > 0.10
# Average Levenshtein Distance between deprel    -0.06 < 0.06 > 0.12
# Average NP Length                               2.05 < 2.17 > 2.29
# Complex NP Ratio                                0.58 < 0.62 > 0.67
# Number of Combined Clauses                      0.99 < 1.19 > 1.37
# Number of Coordinate Clauses                    0.22 < 0.31 > 0.40
# Number of Subordinate Clauses                   0.72 < 0.87 > 1.02
# Coordinate to Combined Clause Ratio             0.11 < 0.16 > 0.21
# Subordinate to Combined Clause Ratio            0.39 < 0.46 > 0.53
# Coordinate to Subordinate Clause Ratio          0.08 < 0.14 > 0.19
# Coordinate Clause to Sentence Ratio             0.22 < 0.31 > 0.40
# Subordinate Clause to Sentence Ratio            0.71 < 0.87 > 1.02
# ROOT_ratio                                      0.57 < 0.62 > 0.67
# root_ratio                                      0.00 < 0.00 > 0.00
# acl_ratio                                       0.02 < 0.04 > 0.06
# acl:relcl_ratio                                 0.01 < 0.02 > 0.04
# advcl_ratio                                     0.05 < 0.08 > 0.10
# advcl:relcl_ratio                               0.00 < 0.00 > 0.00
# ccomp_ratio                                     0.01 < 0.02 > 0.03
# csubj_ratio                                     0.01 < 0.03 > 0.04
# csubj:outer_ratio                               0.00 < 0.00 > 0.00
# nsubj:outer_ratio                               0.00 < 0.00 > 0.00
# parataxis_ratio                                 0.01 < 0.03 > 0.05
# xcomp_ratio                                     0.06 < 0.09 > 0.11
# conj_ratio                                      0.05 < 0.07 > 0.09
